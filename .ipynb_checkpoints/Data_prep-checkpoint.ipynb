# %% [markdown]
# # Maryland Crash Data Exploration
# Data cleaning done to update bike stress data for the City of College Park.

# %%
# Import modules
import pandas as pd
import numpy as np
import geopandas

# %% [markdown]
# ## Loading raw data

# %%
non_motorists_raw = pd.read_csv('data/Crash_NonMotorists_data_raw.csv') #Crash data for non-motorists
general_crash_data = pd.read_csv('data/Crash_data_raw.csv') #Crash data for general cases
non_motorists_raw.head(5)
# Out:
#   Crash Severity Description Reportnumber  \
# 0              Fatal Crashes  MSP5121000P
# 1              Fatal Crashes   DA36550097
# 2              Fatal Crashes  MSP556300B5
# 3             Injury Crashes   DA4401000X
# 4             Injury Crashes  MSP718600HV
#
#                           Type NM Description  \
# 0                                  Pedestrian
# 1                                  Pedestrian
# 2                                  Pedestrian
# 3                          Scooter (electric)
# 4  Occupant of Motor Vehicle Not in Transport
#
#                             PersonID NM  ActionPriorToCrash NM  \
# 0  02180e97-d5ec-42e4-ba4e-a6c7800dc4e2                      0
# 1  af7f440b-b3ad-4a72-afe0-ee8c8abb8890                    100
# 2  b70c203f-7e57-42d8-9fb7-5c34666a8883                    101
# 3  2c9274ab-5c85-49b1-a34d-f942e33eca52                    100
# 4  36bac7ee-97ab-404f-8d44-a40dc64e321e                     98
#
# ...

# %%
general_crash_data.head(5) #Will get the lat/lon data from this dataset
# Out:
#   Crash Severity Description Reportnumber CollisionImpact Description  \
# 0                        NaN   ZP05430003                         NaN
# 1                        NaN   ZP05350003                         NaN
# 2                        NaN   ZP05350002                         NaN
# 3                        NaN   ZP05190004                         NaN
# 4                        NaN   ZP05190003                         NaN
#
#   Crash County Description Large Vehicle Involved Motorcycle Crash  \
# 0                      NaN                    NaN              NaN
# 1                      NaN                    NaN              NaN
# 2                      NaN                    NaN              NaN
# 3                      NaN                    NaN              NaN
# 4                      NaN                    NaN              NaN
#
#   Non-Motorist Crash Person ID Contribs PersonID NM PersonID NMSafetyEquip  \
# ...

# %% [markdown]
# ## Cleaning data

# %%
non_motorist_tidy = pd.merge(non_motorists_raw, general_crash_data[['Reportnumber', 'Latitude (generated)','Longitude (generated)']], on='Reportnumber', how='left')
non_motorist_tidy.head(5)
# Out:
#   Crash Severity Description Reportnumber Type NM Description  \
# 0              Fatal Crashes  MSP5121000P          Pedestrian
# 1              Fatal Crashes  MSP5121000P          Pedestrian
# 2              Fatal Crashes   DA36550097          Pedestrian
# 3              Fatal Crashes   DA36550097          Pedestrian
# 4              Fatal Crashes  MSP556300B5          Pedestrian
#
#                             PersonID NM  ActionPriorToCrash NM  \
# 0  02180e97-d5ec-42e4-ba4e-a6c7800dc4e2                      0
# 1  02180e97-d5ec-42e4-ba4e-a6c7800dc4e2                      0
# 2  af7f440b-b3ad-4a72-afe0-ee8c8abb8890                    100
# 3  af7f440b-b3ad-4a72-afe0-ee8c8abb8890                    100
# 4  b70c203f-7e57-42d8-9fb7-5c34666a8883                    101
#
#   ActionPriorToCrash NM Description  Age NM        City NM  ContactPoint NM  \
# 0                               NaN      33      RIVERDALE                3
# ...

# %%
non_motorist_tidy.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 410 entries, 0 to 409
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Crash Severity Description         410 non-null    object
#  1   Reportnumber                       410 non-null    object
#  2   Type NM Description                410 non-null    object
#  3   PersonID NM                        410 non-null    object
#  4   ActionPriorToCrash NM              410 non-null    int64
#  5   ActionPriorToCrash NM Description  386 non-null    object
#  6   Age NM                             410 non-null    int64
#  7   City NM                            410 non-null    object
#  8   ContactPoint NM                    410 non-null    int64
#  9   ContactPoint NM Description        410 non-null    object
#  10  DistractedByAction NM              410 non-null    int64
# ...

# %% [markdown]
# ### Classes of non-motorists

# %%
for i in non_motorist_tidy["Type NM Description"].unique():
    print('*' + i + '\n')
# Out:
# *Pedestrian
#
# *Scooter (electric)
#
# *Occupant of Motor Vehicle Not in Transport
#
# *Unknown Type Of Non-Motorist
#
# *Cyclist (Electric)
#
# *Cyclist (non-electric)
#
# *Occupant Of a Non-Motor Vehicle Transportation Device
#
# *Unknown
#
# *Scooter (non-Electric)
#
# *Other Pedestrian (person in a building, skater, personal conveyance, etc.)

# %% [markdown]
# We will use:
# * Scooter (electric)
# * Cyclist (Electric)
# * Cyclist (non-electric)
# * Scooter (non-Electric)

# %%
# Create list of desired classes
non_motorists_classes = ["Scooter (electric)","Cyclist (Electric)","Cyclist (non-electric)","Scooter (non-Electric)"]
#Use list to filter dataframe
non_motorist_tidy = non_motorist_tidy[non_motorist_tidy['Type NM Description'].isin(non_motorists_classes)] #Filter by list values
non_motorist_tidy.info() #Describe output table
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 6 to 409
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Crash Severity Description         60 non-null     object
#  1   Reportnumber                       60 non-null     object
#  2   Type NM Description                60 non-null     object
#  3   PersonID NM                        60 non-null     object
#  4   ActionPriorToCrash NM              60 non-null     int64
#  5   ActionPriorToCrash NM Description  60 non-null     object
#  6   Age NM                             60 non-null     int64
#  7   City NM                            60 non-null     object
#  8   ContactPoint NM                    60 non-null     int64
#  9   ContactPoint NM Description        60 non-null     object
#  10  DistractedByAction NM              60 non-null     int64
# ...

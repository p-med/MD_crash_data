# %% [markdown]
# # College Park Calendar Year 2024 Crash Data Analysis
#
# **Data Source:** https://mdsp.maryland.gov/Pages/Dashboards/CrashDataDashboard.aspx
# **Time Period:** Jan 2024 - Dec 2024
#
# ## Methodology
#
# * Data will be extracted from the MSP Crash Data Dashboard.
# * Crashes will be filtered to include only those occurring within the College Park municipal limits.
# * Spatial analysis will be conducted to identify crash hotspots.
# * Statistical analysis will be performed to identify trends related to:
# * Most frequent crash locations (intersections, street segments).
# * Common crash types (e.g., rear-end, angle, sideswipe).
# * Time of day/day of week patterns.
# * Contributing factors (e.g., distracted driving, speed, failure to yield).
# * Injury severity distribution.
# * Any inconsistencies or missing data points will be noted.
# ## Key Findings

# %% [markdown]
# ## Data Preparation
#
# Load libraries

# %%
import pandas as pd
import numpy as np
import geopandas
import matplotlib.pyplot as plt
import datetime
import math
from dateutil.relativedelta import relativedelta
from IPython.display import Image

# %% [markdown]
# ### Load data

# %%
general_crash_data_2024 = pd.read_csv('./raw_data/CrashCounts_Reports_data.csv')
non_motorist_crash_data_2024 = pd.read_csv('./raw_data/CrashCounts_NonMotorists_data.csv')
# Out:
# C:\Users\pmedina\AppData\Local\Temp\ipykernel_19104\1072871256.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   general_crash_data_2024 = pd.read_csv('./raw_data/CrashCounts_Reports_data.csv')

# %%
non_motorist_crash_data_2024.head(5)
# Out:
#       Type NM Description                           PersonID NM  \
# 0  Cyclist (non-electric)  ebbd3c7c-cd77-49da-873b-cada6a4576e5
# 1              Pedestrian  bef84824-8980-483e-a8fa-85037292daae
# 2              Pedestrian  1a8f99d7-1ef8-4711-b94d-82077f3d1621
# 3      Cyclist (Electric)  4918bb20-61cf-4d08-a1c9-6f700bbc195b
# 4              Pedestrian  7957d0d1-8da9-42da-bd6f-5b5e815bfd7f
#
#   ReportNumber NM  ActionPriorToCrash NM  \
# 0      AA0073002X                      6
# 1      AA0073003H                     98
# 2      AA00850047                    101
# 3      AA0085004K                      6
# 4      AA01230052                    100
#
#                    ActionPriorToCrash NM Description  Age NM   City NM  \
# 0  Walking/Cycling Along Roadway With Traffic (In...      19  ABERDEEN
# 1                                              Other      57  EDGEWOOD
# 2                    Cross/Enter Not at Intersection      47  ABERDEEN
# 3  Walking/Cycling Along Roadway With Traffic (In...      32  ABERDEEN
# 4                        Cross/Enter at Intersection      48  ABERDEEN
#
#    ContactPoint NM ContactPoint NM Description  DistractedByAction NM  ...  \
# 0                3                       Right                      0  ...
# 1               12                       Front                      0  ...
# 2                3                       Right                     99  ...
# 3                9                        Left                      0  ...
# 4                9                        Left                      0  ...
#
#   InjuryStatus NM Description  Location NM          Location NM Description  \
# 0      Suspected Minor Injury            3             Intersection – Other
# 1      Suspected Minor Injury           98                            Other
# 2                Fatal Injury            7     Travel Lane – Other Location
# 3      Suspected Minor Injury            3             Intersection – Other
# 4      Suspected Minor Injury            1  Intersection – Marked Crosswalk
#
#   OriginDestination NM  OriginDestination NM Description State NM  \
# 0                    2                           Transit       MD
# 1                   97                    Not Applicable       MD
# 2                   97                    Not Applicable       MD
# 3                   97                    Not Applicable       MD
# 4                   97                    Not Applicable       MD
#
#                        StruckByVehID NM Type NM  Unknown NM ZipCode NM
# 0  13a105ad-040f-43c8-979f-b8d05d497f3f     101           N      21001
# 1  619dc5f9-4e02-4e2d-8a3c-fb24a2cfd35a       6           N      21009
# 2  21812834-6dd1-4026-aeb2-cdab9b734017       6           N      21001
# 3  b8de8cc1-3e29-45c4-b166-87bd782b39be     100           N      21001
# 4  cfd16d36-8693-42ef-8825-7eb8356b08ba       6           N      21001
#
# [5 rows x 27 columns]

# %%
general_crash_data_2024.head(5)
# Out:
#   Crash County Description Crash Severity Description Reportnumber  \
# 0               St. Mary's    Property Damage Crashes   ZR0390003K
# 1                  Charles             Injury Crashes  MSP77400007
# 2                Frederick    Property Damage Crashes  MSP743400JS
# 3                  Harford              Fatal Crashes  MSP713100CG
# 4             Anne Arundel             Injury Crashes   AC2586001Q
#
#                              Agencyname CollisionImpact Description  \
# 0  Saint Mary's County Sheriff's Office              Single Vehicle
# 1                 Maryland State Police              Single Vehicle
# 2                 Maryland State Police   Sideswipe, Same Direction
# 3                 Maryland State Police              Single Vehicle
# 4            Anne Arundel County Police               Front to Rear
#
#   FunctionalClass Description ImpairedCrash Large Vehicle Involved  \
# 0             Major Collector            No                     No
# 1             Major Collector            No                     No
# 2                  Interstate            No                    Yes
# 3                  Interstate            No                     No
# 4                       Local            No                     No
#
#   Motorcycle Crash Non-Motorist Crash  ... Surface Description  \
# 0               No                 No  ...                 Wet
# 1               No                 No  ...                 Dry
# 2               No                 No  ...                 Dry
# 3               No                 No  ...                 Wet
# 4               No                 No  ...                 Dry
#
#    TrafficControl Trafficcontrol Description Work Zone Crash  \
# 0             NaN                        NaN              No
# 1             NaN                        NaN              No
# 2             NaN                        NaN              No
# 3             NaN                        NaN              No
# 4             1.0                 Signalized              No
#
#    WZLawEnforcementPresent WZLocation WZLocation Description WZType  \
# 0                      NaN        NaN                    NaN    NaN
# 1                      NaN        NaN                    NaN    NaN
# 2                      NaN        NaN                    NaN    NaN
# 3                      NaN        NaN                    NaN    NaN
# 4                      NaN        NaN                    NaN    NaN
#
#   WZType Description WZWorkersPresent
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
#
# [5 rows x 72 columns]

# %% [markdown]
# ### Consolidate datasets
#
# Merge both datasets by report number.

# %%
consolidated_crash_data_2024 = general_crash_data_2024.merge(non_motorist_crash_data_2024, left_on='Reportnumber', right_on='ReportNumber NM', how='left')

# %% [markdown]
# ### Clip data to College Park limits
#
# Clip features to CP boundaries.

# %% [markdown]
# Load CP boundaries.

# %%
cp = geopandas.read_file("data/boundaries/College_Park_City_Limits.shp")
cp = cp.to_crs(4326)
cp.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
#Load consolidated dataset as geopandas object
gdf = geopandas.GeoDataFrame(
    consolidated_crash_data_2024, geometry=geopandas.points_from_xy(consolidated_crash_data_2024.Longitude, consolidated_crash_data_2024.Latitude), crs="EPSG:4326"
)

# %%
ax = cp.plot(color="white", edgecolor="black")

# We can now plot our ``GeoDataFrame``.
gdf.plot(ax=ax, color="red")

plt.show()

# %%
#Clip dataset
consolidated_CP_crash_data_2024 = geopandas.clip(gdf, cp)
ax = cp.plot(color="white", edgecolor="black") #Load boundaries
consolidated_CP_crash_data_2024.plot(ax=ax, color="red") #Load clipped points

plt.show() #Plot

# %%
#Save dataset
consolidated_CP_crash_data_2024.to_csv('tidy_data/consolidated_data.csv')

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Time series

# %%
consolidated_CP_crash_data_2024.head(5)
# Out:
#        Crash County Description Crash Severity Description Reportnumber  \
# 105324          Prince George's             Injury Crashes   DA418100DD
# 56693           Prince George's    Property Damage Crashes   DA4050005V
# 42792           Prince George's    Property Damage Crashes   DA14540004
# 16239           Prince George's    Property Damage Crashes   DA418600BK
# 59128           Prince George's    Property Damage Crashes   DA43790012
#
#                            Agencyname CollisionImpact Description  \
# 105324  Prince George's County Police                       Other
# 56693   Prince George's County Police              Single Vehicle
# 42792   Prince George's County Police              Single Vehicle
# 16239   Prince George's County Police   Sideswipe, Same Direction
# 59128   Prince George's County Police                Rear To Side
#
#        FunctionalClass Description ImpairedCrash Large Vehicle Involved  \
# 105324  Principal Arterial – Other            No                     No
# 56693                          NaN            No                     No
# 42792                        Local            No                     No
# 16239   Principal Arterial – Other            No                     No
# 59128   Principal Arterial – Other            No                     No
#
#        Motorcycle Crash Non-Motorist Crash  ... Location NM  \
# 105324               No                 No  ...         NaN
# 56693                No                 No  ...         NaN
# 42792                No                 No  ...         NaN
# 16239                No                 No  ...         NaN
# 59128                No                 No  ...         NaN
#
#         Location NM Description OriginDestination NM  \
# 105324                      NaN                  NaN
# 56693                       NaN                  NaN
# 42792                       NaN                  NaN
# 16239                       NaN                  NaN
# 59128                       NaN                  NaN
#
#        OriginDestination NM Description  State NM StruckByVehID NM Type NM  \
# 105324                              NaN       NaN              NaN     NaN
# 56693                               NaN       NaN              NaN     NaN
# 42792                               NaN       NaN              NaN     NaN
# 16239                               NaN       NaN              NaN     NaN
# 59128                               NaN       NaN              NaN     NaN
#
#        Unknown NM ZipCode NM                geometry
# 105324        NaN        NaN  POINT (-76.938 38.974)
# 56693         NaN        NaN  POINT (-76.928 38.975)
# 42792         NaN        NaN  POINT (-76.916 38.976)
# 16239         NaN        NaN  POINT (-76.938 38.976)
# 59128         NaN        NaN  POINT (-76.938 38.977)
#
# [5 rows x 100 columns]

# %%
consolidated_CP_crash_data_2024['Crashdate']
# Out:
# 105324     6/28/2024
# 56693       5/4/2024
# 42792      1/20/2024
# 16239      12/5/2024
# 59128     11/20/2024
#              ...
# 89129      7/29/2024
# 75486      7/23/2024
# 22930      12/7/2024
# 70137      6/13/2024
# 52352     12/20/2024
# Name: Crashdate, Length: 542, dtype: object

# %%
consolidated_CP_crash_data_2024['Crashdate'] = pd.to_datetime(consolidated_CP_crash_data_2024.Crashdate)
# Out:
# C:\Users\pmedina\AppData\Local\anaconda3\Lib\site-packages\geopandas\geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
consolidated_CP_crash_data_2024['month_n'] = consolidated_CP_crash_data_2024['Crashdate'].dt.strftime("%m")
consolidated_CP_crash_data_2024['month_name'] = consolidated_CP_crash_data_2024['Crashdate'].dt.strftime("%B")
# Out:
# C:\Users\pmedina\AppData\Local\anaconda3\Lib\site-packages\geopandas\geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# C:\Users\pmedina\AppData\Local\anaconda3\Lib\site-packages\geopandas\geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
from matplotlib.pyplot import figure
figure(figsize=(15, 5), dpi=80)
plt.plot(consolidated_CP_crash_data_2024.groupby('month_n')['Reportnumber'].count())

# %% [markdown]
# ### Clustering
# Clustering analysis was done based on:
# * General accident distribution
# * Distribution based on crash severity
# * Distribution based on non-motorists crashes

# %% [markdown]
# #### General accident distribution

# %% [markdown]
# #### Distribution based on crash severity
#
# Based on the results, the crash severity does not have a clustering pattern

# %%
ax = cp.plot(color="white", edgecolor="black") #Load boundaries
consolidated_CP_crash_data_2024.plot(ax=ax, 
                                     column='Crash Severity Description', 
                                     legend=True,
                                    legend_kwds={'bbox_to_anchor': (1, 1)}) 
#Load clipped points with symbology by crash severity

plt.show() #Plot

# %% [markdown]
# ##### ArcGIS Pro Cluster analysis

# %%
Image(url="images/crash_severity_cluster_analisys.png", width=500)
